# %% [markdown]
# # Who are our top performers? Find matching locations
# ---
# ### Summary
#     1. Import Modules
#     2. Request JSON Through Census API, Convert To Pandas DF
#     3. Clean Data
#         A. Drop Useless Columns
#         B. Rename Columns
#         C. Datatypes Format
#         D. Null and Negative Values
#     4. Data Exploration
#         A. Import CSV With Zip Frequency And Monetary Values
#         B. What Are The Demographics Of Our Top Zips?
#     5. Compares Differences
#         A. Create Differences Function
#         B. Pivot Data
#         C. Findings
#     6. Save Data

# %% [markdown]
# ## 1. Import Modules

# %%
import pandas as pd
import requests

# See all data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## 2. Request JSON Through Census API, Convert To Pandas DF

# %%
# Demographics we will use:
# -total population B01001_001E 
# -median age B01002_001E 
# -home age median B25035_001E 
# -median home value B25107_001E 
# -median household income last 12 mo B19013_001E 
# -home owner lived in unit B07013_002E

api_variables = "B01001_001E,B01002_001E,B25035_001E,B25107_001E,B19013_001E,B07013_002E"
url = "https://api.census.gov/data/2019/acs/acs5?get={}&for=zip%20code%20tabulation%20area:*&in=state:08"\
                                                                                    .format(api_variables)

payload={}
headers = {
  'Cookie': 'TS010383f0=011ba694f273cea421f27bf0ab2cac56fcf022cae435637d6ff0\
                      4b48f22db0da4930c5fdccf2e3ecfe07edeb712ddebd5998d53170'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
def json_to_dataframe(response):
    """
    Convert response to dataframe
    """
    return pd.DataFrame(response.json()[1:], columns=response.json()[0])

# %%
df = json_to_dataframe(response)

df.head(2)
# Out:
#   B01001_001E B01002_001E B25035_001E B25107_001E B19013_001E B07013_002E  \
# 0  42          59.0        0           -666666666  27000       42
# 1  4257        48.7        1995        276800      68272       2864
#
#   state zip code tabulation area
# 0  08    80434
# 1  08    80446

# %% [markdown]
# ## 4. Clean Data

# %% [markdown]
# ### A. Drop Useless Columns

# %%
df = df.drop(columns=["state"])

df.head(1)
# Out:
#   B01001_001E B01002_001E B25035_001E B25107_001E B19013_001E B07013_002E  \
# 0  42          59.0        0           -666666666  27000       42
#
#   zip code tabulation area
# 0  80434

# %% [markdown]
# ### B. Rename Columns

# %%
column_update = ["population", #B01001_001E
                 "median_age", #B01002_001E
                 "median_home_age", #B25035_001E
                 "median_home_value", #B25107_001E
                 "median_income", #B19013_001E
                 "owner_occ", # B07013_002E
                 "zip"]

df.columns = column_update

# %%
df.head()
# Out:
#   population median_age median_home_age median_home_value median_income  \
# 0  42         59.0       0               -666666666        27000
# 1  4257       48.7       1995            276800            68272
# 2  2328       48.3       1983            381300            74809
# 3  15858      34.5       1970            203500            57234
# 4  7180       37.0       1972            171800            46897
#
#   owner_occ    zip
# 0  42        80434
# 1  2864      80446
# 2  1431      80447
# 3  9818      80701
# 4  4784      80723

# %% [markdown]
# ### C. Datatypes Format

# %%
df.dtypes
# Out:
# population           object
# median_age           object
# median_home_age      object
# median_home_value    object
# median_income        object
# owner_occ            object
# zip                  object
# dtype: object

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# population           int64
# median_age           float64
# median_home_age      int64
# median_home_value    int64
# median_income        int64
# owner_occ            int64
# zip                  int64
# dtype: object

# %% [markdown]
# ### D. Null Or Negative Values

# %%
# Check for null values
df.isnull().sum()
# Out:
# population           0
# median_age           0
# median_home_age      0
# median_home_value    0
# median_income        0
# owner_occ            0
# zip                  0
# dtype: int64

# %%
# Check for negative numbers
# Census data that is negative signifies no data collected
df.lt(0).sum()
# Out:
# population           0
# median_age           18
# median_home_age      20
# median_home_value    54
# median_income        47
# owner_occ            0
# zip                  0
# dtype: int64

# %%
# Check to see if zips with negative values are usefull
df[(df < 0).values].head()
# Out:
#     population   median_age  median_home_age  median_home_value  \
# 0   42          59.0         0               -666666666
# 12  3728        21.7         2006            -666666666
# 18  0          -666666666.0  1987            -666666666
# 18  0          -666666666.0  1987            -666666666
# 18  0          -666666666.0  1987            -666666666
#
#     median_income  owner_occ    zip
# 0   27000          42         80434
# 12  54732          0          80913
# 18 -666666666      0          80448
# 18 -666666666      0          80448
# 18 -666666666      0          80448

# %%
# We are going to drop all rows with negative values because they all have a very low population, are a military base,
# or have multiple negative values making them useless
df = df[df > 0].dropna()
df.lt(0).sum()
# Out:
# population           0
# median_age           0
# median_home_age      0
# median_home_value    0
# median_income        0
# owner_occ            0
# zip                  0
# dtype: int64

# %% [markdown]
# ## 5. Data Exploration

# %% [markdown]
# ### A. Import CSV With Zip Frequency And Monetary Values

# %%
df_f_m = pd.read_csv("zip_f_m.csv")

# %% [markdown]
# ### B. What Are The Demographics Of Our Top Zips?

# %%
# Top zips by total monetary value spent
df_f_m[df_f_m['label'] == 'Top'].sort_values('monetary_sum', ascending=False).head(5)
# Out:
#    location_zip  frequency_count  monetary_sum  f_score  m_score  score_total  \
# 0  80919         1653             489861.74     1        1        2
# 1  80920         1641             466744.75     1        1        2
# 4  80906         1236             449015.50     1        1        2
# 2  80921         1309             347282.33     1        1        2
# 3  80132         1268             311673.35     1        1        2
#
#   label
# 0  Top
# 1  Top
# 4  Top
# 2  Top
# 3  Top

# %%
# Top zips by total appointments 
df_f_m[df_f_m['label'] == 'Top'].sort_values('frequency_count', ascending=False).head(5)
# Out:
#    location_zip  frequency_count  monetary_sum  f_score  m_score  score_total  \
# 0  80919         1653             489861.74     1        1        2
# 1  80920         1641             466744.75     1        1        2
# 2  80921         1309             347282.33     1        1        2
# 3  80132         1268             311673.35     1        1        2
# 4  80906         1236             449015.50     1        1        2
#
#   label
# 0  Top
# 1  Top
# 2  Top
# 3  Top
# 4  Top

# %%
# Create array of selected zips
df_list = df_f_m[df_f_m['label'] == 'Top'].sort_values('monetary_sum', ascending=False).head(5)
zip_array = df_list['location_zip'].tolist()
zip_array
# Out:
# [80919, 80920, 80906, 80921, 80132]

# %%
# Demographics of top zips
top_zip_demos = df[df['zip'].isin(zip_array)]
top_zip_demos
# Out:
#      population  median_age  median_home_age  median_home_value  \
# 33   40016.0     35.6        1992.0           332000.0
# 89   28039.0     43.6        1988.0           373500.0
# 311  37608.0     39.1        1984.0           357800.0
# 312  24087.0     41.5        2004.0           444900.0
# 389  21286.0     43.9        1996.0           474200.0
#
#      median_income  owner_occ    zip
# 33   96284.0        28689.0    80920
# 89   95320.0        21143.0    80919
# 311  68701.0        23312.0    80906
# 312  124085.0       19779.0    80921
# 389  129009.0       19009.0    80132

# %% [markdown]
# ## 6. Compares Differences

# %% [markdown]
# ### A. Create Differences Function

# %%
def create_df(target_zip):
    """
    Loop through all CO zips finding the 
    differences between target zip
    demographics
    """
    arr = [] 
    for index, row in df.iterrows(): 
        for column in df.columns:   
            if column != 'zip':
                target_zip_data = df[df['zip'] == target_zip]['{}'.format(column)].iat[0]
                other_zip_data = row['{}'.format(column)]

                case = {"selected_zip": int(target_zip), "comparing_zip": int(row['zip']), "category": column, "selected_zip_data": target_zip_data, 
                                "comparing_zip_data": other_zip_data, "difference": abs(target_zip_data-other_zip_data),
                                "difference_percent": abs(target_zip_data-other_zip_data) / ((target_zip_data + other_zip_data) / 2) * 100}
                arr.append(case)
    created_df = pd.DataFrame(arr)
    return created_df

# %%
df_80920 = create_df(80920)
df_80906 = create_df(80906)
df_80921 = create_df(80921)
df_80132 = create_df(80132)
df_80919 = create_df(80919)
df_80919.head(6)
# Out:
#    selected_zip  comparing_zip           category  selected_zip_data  \
# 0  80919         80446          population         28039.0
# 1  80919         80446          median_age         43.6
# 2  80919         80446          median_home_age    1988.0
# 3  80919         80446          median_home_value  373500.0
# 4  80919         80446          median_income      95320.0
# 5  80919         80446          owner_occ          21143.0
#
#    comparing_zip_data  difference  difference_percent
# 0  4257.0              23782.0     147.275204
# 1  48.7                5.1         11.050921
# 2  1995.0              7.0         0.351494
# 3  276800.0            96700.0     29.740120
# 4  68272.0             27048.0     33.067632
# 5  2864.0              18279.0     152.280585

# %% [markdown]
# ### B. Pivot Data

# %%
def create_piv(df, zip_string):
    """
    Pivot the df, aggregate all values,
    top 10 lowest values sorted saved 
    as CSV
    """
    piv = df.pivot(index='comparing_zip',
              columns='category',
              values='difference_percent')
    piv['mean_diffs']= piv.mean(axis=1)           
    piv['selected_zip'] = zip_string
    piv = piv.sort_values('mean_diffs').head(11) 
    return piv

# %%
# Concat all dfs to final pivot df
final_piv = pd.concat([create_piv(df_80920, "80920"), create_piv(df_80906, "80906"), 
                      create_piv(df_80921, "80921"), create_piv(df_80132, "80132"),
                      create_piv(df_80919, "80919")])

# %%
# Final data
final_piv = final_piv.reset_index()
final_piv.head()
# Out:
# category  comparing_zip  median_age  median_home_age  median_home_value  \
# 0         80920          0.000000    0.000000         0.000000
# 1         80241          3.042877    0.100351         2.174885
# 2         80128          14.099217   0.503271         13.036745
# 3         80601          6.376812    0.350789         5.668267
# 4         80031          6.784261    0.352024         4.964018
#
# category  median_income  owner_occ  population  mean_diffs selected_zip
# 0         0.000000       0.000000   0.000000    0.000000    80920
# 1         6.129243       10.468784  17.318815   6.539159    80920
# 2         1.289891       3.345101   9.368092    6.940386    80920
# 3         23.969667      7.504114   1.856849    7.621083    80920
# 4         15.696004      6.898044   11.286086   7.663406    80920

# %% [markdown]
# ### C. Findings

# %%
# Zip code mode, sorted
zip_modes = final_piv['comparing_zip'].mode().tolist()
final_piv[(final_piv['comparing_zip'].isin(zip_modes))&(~final_piv['comparing_zip'].isin(zip_array))].sort_values('mean_diffs')
# Out:
# category  comparing_zip  median_age  median_home_age  median_home_value  \
# 23        80109          13.642214   0.049888         1.028623
# 14        80003          5.519054    0.454660         11.528229
# 35        80023          5.620609    0.499750         21.005945
# 25        80023          0.000000    0.099751         27.290373
# 36        80403          5.140187    0.301054         12.011893
# 2         80128          14.099217   0.503271         13.036745
# 37        80109          19.225968   0.449888         5.348057
# 16        80031          2.590674    0.050391         2.518749
# 26        80130          10.126582   0.400000         2.288635
# 4         80031          6.784261    0.352024         4.964018
# 18        80228          1.270648    0.302877         11.906952
# 38        80908          6.588235    0.350088         1.215678
# 47        80550          12.942613   0.701754         5.316654
# 27        80528          16.710183   0.049913         0.315173
# 5         80537          14.583333   0.352024         0.331875
# 20        80120          5.714286    0.454660         12.055154
# 28        80403          0.480769    0.701052         18.352557
# 21        80537          5.230386    0.050391         7.811819
# 49        80104          16.109046   0.601805         4.603714
# 29        80439          14.317673   1.255335         21.145729
# 31        80908          0.968523    0.049913         7.590010
# 51        80120          5.176471    0.656069         7.771487
# 39        80528          22.278481   0.350088         6.690640
# 6         80550          7.307172    0.500751         17.054691
# 41        80439          8.714597    0.855346         14.819877
# 52        80228          9.615385    0.504286         7.622972
# 8         80104          4.126547    0.400802         16.346287
# 53        80128          6.146572    0.302267         1.276935
# 10        80003          3.856749    0.857071         4.056546
# 43        80130          15.724816   0.000000         4.088659
#
# category  median_income  owner_occ  population  mean_diffs selected_zip
# 23        1.067727       0.511950   1.767465    3.011311    80921
# 14        3.837852       6.795956   3.045028    5.196796    80906
# 35        1.113839       1.633143   6.248720    6.020334    80132
# 25        5.004341       2.337536   6.109614    6.806936    80921
# 36        12.323796      7.459551   3.766902    6.833897    80132
# 2         1.289891       3.345101   9.368092    6.940386    80920
# 37        2.823611       3.458526   10.584859   6.981818    80132
# 16        17.976843      13.831656  5.090731    7.009841    80906
# 26        1.498936       12.752059  18.481885   7.591350    80921
# 4         15.696004      6.898044   11.286086   7.663406    80920
# 18        18.955385      4.363880   9.751949    7.758615    80906
# 38        15.214971      10.468625  13.978035   7.969272    80132
# 47        1.651173       19.054751  8.470235    8.022863    80919
# 27        17.671024      10.381322  6.189009    8.552771    80921
# 5         28.697656      2.678955   8.533595    9.196240    80920
# 20        3.673566       17.022366  16.452035   9.228678    80906
# 28        8.442873       11.421394  16.094738   9.248897    80921
# 21        4.855810       23.327018  14.718380   9.332301    80906
# 49        7.259124       15.767346  11.695573   9.339435    80919
# 29        8.493657       7.423995   3.555846    9.365373    80921
# 31        11.340711      14.423937  26.211495   10.097431   80921
# 51        28.870534      7.294475   12.854997   10.437339   80919
# 39        21.525068      6.417635   6.169326    10.571873   80132
# 6         0.644958       11.395413  26.928475   10.638577   80920
# 41        12.374477      11.385905  15.884961   10.672527   80132
# 52        13.713587      14.107045  19.539823   10.850516   80919
# 8         6.254024       14.693832  23.746820   10.928052   80920
# 53        0.283658       33.545898  26.044607   11.266656   80919
# 10        37.155630      13.933372  9.244928    11.517383   80920
# 43        2.392457       16.701220  30.653566   11.593453   80132

# %% [markdown]
# ## 7. Save Data

# %%
# Save final csv files
df.to_csv("all_zip_demos.csv", encoding='utf-8', index=True)
top_zip_demos.to_csv("top_zip_demos.csv", encoding='utf-8', index=True)
final_piv.to_csv("final_piv.csv", encoding='utf-8', index=True)
