# %% [markdown]
# # Who Are Our Future Zip Codes According To Census Data?
# ---
# ### Summary
#     1. Import Modules
#     2. Define Census Variables/Tables
#     3. Request JSON Through Census API, Convert To Pandas DF
#     4. Clean Data
#         A. Drop Useless Columns
#         B. Rename Columns
#         C. Datatypes Format
#     5. Data Exploration
#         A. Import CSV With Zip Frequency And Monetary Values
#         B. What Are The Demographics Of Our Top Zips?
#     6. Create Function That Compares Differences
#     7. Save Data

# %% [markdown]
# ## 1. Import Modules

# %%
import pandas as pd
import requests

# See all data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-1-163dffb5dca6>:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## 2. Define Census Variables/Tables

# %%
# Demographics we will use:

# -total population B01001_001E *
# -median age B01002_001E *
# -home age median B25035_001E *
# -median home value B25107_001E *
# -median household income last 12 mo B19013_001E *

api_variables = "B01001_001E,B01002_001E,B25035_001E,B25107_001E,B19013_001E"

# %% [markdown]
# ## 3. Request JSON Through Census API, Convert To Pandas DF

# %%
url = "https://api.census.gov/data/2019/acs/acs5?get={}&for=zip%20code%20tabulation%20area:*&in=state:08".format(api_variables)

payload={}
headers = {
  'Cookie': 'TS010383f0=011ba694f273cea421f27bf0ab2cac56fcf022cae435637d6ff04b48f22db0da4930c5fdccf2e3ecfe07edeb712ddebd5998d53170'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
def json_to_dataframe(response):
    """
    Convert response to dataframe
    """
    return pd.DataFrame(response.json()[1:], columns=response.json()[0])

# %%
df = json_to_dataframe(response)

df.head(1)
# Out:
#   B01001_001E B01002_001E B25035_001E B25107_001E B19013_001E state  \
# 0  42          59.0        0           -666666666  27000       08
#
#   zip code tabulation area
# 0  80434

# %% [markdown]
# ## 4. Clean Data

# %% [markdown]
# ### A. Drop Useless Columns

# %%
df = df.drop(columns=["state"])

df.head(1)
# Out:
#   B01001_001E B01002_001E B25035_001E B25107_001E B19013_001E  \
# 0  42          59.0        0           -666666666  27000
#
#   zip code tabulation area
# 0  80434

# %% [markdown]
# ### B. Rename Columns

# %%
column_update = ["population", #B01001_001E
                 "median_age", #B01002_001E
                 "median_home_age", #B25035_001E
                 "median_home_value", #B25107_001E
                 "median_income", #B19013_001E
                 "zip"]

df.columns = column_update

# %%
df.head(1)
# Out:
#   population median_age median_home_age median_home_value median_income    zip
# 0  42         59.0       0               -666666666        27000         80434

# %% [markdown]
# ### C. Datatypes Format

# %%
df.dtypes
# Out:
# population           object
# median_age           object
# median_home_age      object
# median_home_value    object
# median_income        object
# zip                  object
# dtype: object

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# population           int64
# median_age           float64
# median_home_age      int64
# median_home_value    int64
# median_income        int64
# zip                  int64
# dtype: object

# %% [markdown]
# ## 5. Data Exploration

# %% [markdown]
# ### A. Import CSV With Zip Frequency And Monetary Values

# %%
df_f_m = pd.read_csv("zip_f_m.csv")

# %% [markdown]
# ### B. What Are The Demographics Of Our Top Zips?

# %%
# Top zips by total monetary value spent
df_f_m[df_f_m['label'] == 'Top'].sort_values('monetary_sum', ascending=False).head(5)
# Out:
#    location_zip  frequency_count  monetary_sum  f_score  m_score  score_total  \
# 0  80919         1653             489861.74     1        1        2
# 1  80920         1641             466744.75     1        1        2
# 4  80906         1236             449015.50     1        1        2
# 2  80921         1309             347282.33     1        1        2
# 3  80132         1268             311673.35     1        1        2
#
#   label
# 0  Top
# 1  Top
# 4  Top
# 2  Top
# 3  Top

# %%
# Top zips by total appointments 
df_f_m[df_f_m['label'] == 'Top'].sort_values('frequency_count', ascending=False).head(5)
# Out:
#    location_zip  frequency_count  monetary_sum  f_score  m_score  score_total  \
# 0  80919         1653             489861.74     1        1        2
# 1  80920         1641             466744.75     1        1        2
# 2  80921         1309             347282.33     1        1        2
# 3  80132         1268             311673.35     1        1        2
# 4  80906         1236             449015.50     1        1        2
#
#   label
# 0  Top
# 1  Top
# 2  Top
# 3  Top
# 4  Top

# %%
# Create array of selected zips
df_list = df_f_m[df_f_m['label'] == 'Top'].sort_values('monetary_sum', ascending=False).head(5)
zip_array = df_list['location_zip'].tolist()
zip_array
# Out:
# [80919, 80920, 80906, 80921, 80132]

# %%
# Demographics of top zips
top_zip_demos = df[df['zip'].isin(zip_array)]
top_zip_demos
# Out:
#      population  median_age  median_home_age  median_home_value  \
# 33   40016       35.6        1992             332000
# 89   28039       43.6        1988             373500
# 311  37608       39.1        1984             357800
# 312  24087       41.5        2004             444900
# 389  21286       43.9        1996             474200
#
#      median_income    zip
# 33   96284          80920
# 89   95320          80919
# 311  68701          80906
# 312  124085         80921
# 389  129009         80132

# %% [markdown]
# ## 6. Create Function That Compares Differences

# %%
def create_df(target_zip):
    """
    Loop through all CO zips finding the 
    differences between target zip
    demographics
    """
    arr = [] 
    for index, row in df.iterrows(): 
        for column in df.columns:   
            if column != 'zip':
                target_zip_data = df[df['zip'] == target_zip]['{}'.format(column)].iat[0]
                other_zip_data = row['{}'.format(column)]

                case = {"selected_zip": int(target_zip), "comparing_zip": int(row['zip']), "category": column, "selected_zip_data": target_zip_data, 
                                "comparing_zip_data": other_zip_data, "difference": abs(target_zip_data-other_zip_data)}
                arr.append(case)
    created_df = pd.DataFrame(arr)
    return created_df

# %%
df_80920 = create_df(80920)
df_80906 = create_df(80906)
df_80921 = create_df(80921)
df_80132 = create_df(80132)
df_80919 = create_df(80919)
df_80919.head(10)
# Out:
#    selected_zip  comparing_zip           category  selected_zip_data  \
# 0  80919         80434          population         28039.0
# 1  80919         80434          median_age         43.6
# 2  80919         80434          median_home_age    1988.0
# 3  80919         80434          median_home_value  373500.0
# 4  80919         80434          median_income      95320.0
# 5  80919         80446          population         28039.0
# 6  80919         80446          median_age         43.6
# 7  80919         80446          median_home_age    1988.0
# 8  80919         80446          median_home_value  373500.0
# 9  80919         80446          median_income      95320.0
#
#    comparing_zip_data   difference
# 0  42.0                27997.0
# 1  59.0                15.4
# 2  0.0                 1988.0
# 3 -666666666.0         667040166.0
# 4  27000.0             68320.0
# 5  4257.0              23782.0
# 6  48.7                5.1
# 7  1995.0              7.0
# 8  276800.0            96700.0
# 9  68272.0             27048.0

# %%
def create_piv(df, zip_string):
    """
    Pivot the df, aggregate all values,
    top 10 lowest values sorted saved 
    as CSV
    """
    piv = df.pivot(index='comparing_zip',
              columns='category',
              values='difference')
    piv['agg_diffs']= piv.sum(axis=1)
    piv['selected_zip'] = zip_string
    piv = piv.sort_values('agg_diffs').head(10)
    return piv

# %%
# Concat all dfs to final pivot df
final_piv = pd.concat([create_piv(df_80920, "80920"), create_piv(df_80906, "80906"), 
                      create_piv(df_80921, "80921"), create_piv(df_80132, "80132"),
                      create_piv(df_80919, "80919")])

# %%
# Final data
final_piv = final_piv.reset_index()
# Out:
# category  comparing_zip  median_age  median_home_age  median_home_value  \
# 0         80920          0.0         0.0              0.0
# 1         80241          1.1         2.0              7300.0
# 2         80831          2.7         10.0             3800.0
# 3         80537          5.6         7.0              1100.0
# 4         80031          2.5         7.0              16900.0
# 5         80603          0.5         10.0             1400.0
# 6         80601          2.2         7.0              18300.0
# 7         81507          15.2        7.0              4400.0
# 8         80549          0.1         8.0              7700.0
# 9         80538          6.1         2.0              9100.0
# 10        80906          0.0         0.0              0.0
# 11        80524          3.3         0.0              2900.0
# 12        80227          0.0         6.0              9500.0
# 13        80526          7.3         3.0              5300.0
# 14        80021          3.6         7.0              4700.0
# 15        80226          4.4         12.0             11500.0
# 16        80031          1.0         1.0              8900.0
# 17        80234          4.2         5.0              9600.0
# 18        80231          4.7         4.0              17100.0
# 19        80214          3.1         19.0             2500.0
# 20        80921          0.0         0.0              0.0
# 21        80109          5.3         1.0              4600.0
# 22        80130          4.0         8.0              10300.0
# 23        80528          6.4         1.0              1400.0
# 24        80602          3.9         1.0              4800.0
# 25        80924          7.2         7.0              7000.0
# 26        80129          1.3         6.0              15000.0
# 27        80138          1.4         8.0              22900.0
# 28        80125          0.2         7.0              12800.0
# 29        80127          2.3         13.0             4600.0
# 30        80132          0.0         0.0              0.0
# 31        80516          6.4         8.0              1300.0
# 32        80138          3.8         0.0              6400.0
# 33        80908          2.8         7.0              5800.0
# 34        80130          6.4         0.0              19000.0
# 35        80109          7.7         9.0              24700.0
# 36        80107          0.8         2.0              400.0
# 37        80125          2.2         1.0              16500.0
# 38        80126          3.6         1.0              9500.0
# 39        80924          9.6         15.0             22300.0
# 40        80919          0.0         0.0              0.0
# 41        80128          2.6         6.0              4800.0
# 42        80550          5.3         14.0             20400.0
# 43        80018          9.0         17.0             3200.0
# 44        80104          6.5         12.0             17600.0
# 45        80542          8.4         13.0             3500.0
# 46        80020          5.5         0.0              6800.0
# 47        80457          6.2         14.0             2700.0
# 48        80504          6.4         13.0             5900.0
# 49        80004          1.7         15.0             9900.0
#
# category  median_income  population  agg_diffs selected_zip
# 0         0.0            0.0         0.0        80920
# 1         5726.0         6378.0      19407.1    80920
# 2         1641.0         14491.0     19944.7    80920
# 3         24164.0        3567.0      28843.6    80920
# 4         14013.0        4275.0      35197.5    80920
# 5         8794.0         26081.0     36285.5    80920
# 6         20609.0        750.0       39668.2    80920
# 7         11277.0        25063.0     40762.2    80920
# 8         5828.0         27881.0     41417.1    80920
# 9         26829.0        9242.0      45179.1    80920
# 10        0.0            0.0         0.0        80906
# 11        5428.0         1111.0      9442.3     80906
# 12        2276.0         2730.0      14512.0    80906
# 13        1412.0         8663.0      15385.3    80906
# 14        7178.0         3511.0      15399.6    80906
# 15        4929.0         4011.0      20456.4    80906
# 16        13570.0        1867.0      24339.0    80906
# 17        5947.0         9475.0      25031.2    80906
# 18        9719.0         747.0       27574.7    80906
# 19        18183.0        10897.0     31602.1    80906
# 20        0.0            0.0         0.0        80921
# 21        1332.0         422.0       6360.3     80921
# 22        1874.0         4905.0      17091.0    80921
# 23        20147.0        1446.0      23000.4    80921
# 24        7585.0         12175.0     24564.9    80921
# 25        4884.0         13949.0     25847.2    80921
# 26        5767.0         7215.0      27989.3    80921
# 27        2369.0         9484.0      34762.4    80921
# 28        8820.0         13539.0     35166.2    80921
# 29        10431.0        21217.0     36263.3    80921
# 30        0.0            0.0         0.0        80132
# 31        10343.0        6968.0      18625.4    80132
# 32        7293.0         12285.0     25981.8    80132
# 33        18241.0        2781.0      26831.8    80132
# 34        3050.0         7706.0      29762.4    80132
# 35        3592.0         2379.0      30687.7    80132
# 36        22503.0        7812.0      30717.8    80132
# 37        3896.0         10738.0     31137.2    80132
# 38        15.0           22070.0     31589.6    80132
# 39        40.0           11148.0     33512.6    80132
# 40        0.0            0.0         0.0        80919
# 41        270.0          8396.0      13474.6    80919
# 42        1587.0         2480.0      24486.3    80919
# 43        10223.0        14642.0     28091.0    80919
# 44        7180.0         3483.0      28281.5    80919
# 45        2744.0         23121.0     29386.4    80919
# 46        881.0          22452.0     30138.5    80919
# 47        2805.0         27847.0     33372.2    80919
# 48        128.0          27440.0     33487.4    80919
# 49        16734.0        8556.0      35206.7    80919

# %% [markdown]
# ## 7. Save Data

# %%
# Save final csv files

final_piv.to_csv("final_piv.csv", encoding='utf-8', index=True)

top_zip_demos.to_csv("top_zip_demos.csv", encoding='utf-8', index=True)
